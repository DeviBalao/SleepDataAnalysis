# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats

# %%
# Load CSV file into Dataframe
sleep_data_df = pd.read_csv('Resources/Sleep_health_and_lifestyle_dataset.csv')

sleep_data_df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
needed_data_df = sleep_data_df[['Sleep Duration', 'Quality of Sleep', 'Physical Activity Level', 'BMI Category', 'Daily Steps']].copy()
cleaned_data_df = needed_data_df.sort_values('Sleep Duration', ignore_index=True)
cleaned_data_df.head()
# Out:
#    Sleep Duration  Quality of Sleep  Physical Activity Level BMI Category  \
# 0             5.8                 4                       32   Overweight
# 1             5.8                 4                       32   Overweight
# 2             5.9                 6                       90   Overweight
# 3             5.9                 4                       30        Obese
# 4             5.9                 4                       30        Obese
#
#    Daily Steps
# 0         5200
# 1         5200
# 2        10000
# 3         3000
# 4         3000

# %%
needed_data_df.plot(x='Physical Activity Level', y='Sleep Duration', kind='bar')
# Out:
# <Axes: xlabel='Physical Activity Level'>
